# %% [markdown]
# # P3. Redes neuronales
# **Caso Práctico: Fashion-MNIST en Google Colab**
#
# *Aprendizaxe Automática Supervisada*
#
# 3º GrIA. Curso 2025/26

# %% [markdown]
# ---

# %% [markdown]
# # 0. Configuración del entorno

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from keras import initializers

# %%
initializers_list = [
    initializers.RandomNormal,
    initializers.RandomUniform,
    initializers.TruncatedNormal,
    initializers.VarianceScaling,
    initializers.GlorotNormal,
    initializers.GlorotUniform,
    initializers.HeNormal,
    initializers.HeUniform,
    initializers.LecunNormal,
    initializers.LecunUniform,
    initializers.Orthogonal,
]

# %%
# Semilla e inicialización con numpy
SEED_VALUE = 1492
np.random.seed(SEED_VALUE)
keras.utils.set_random_seed(SEED_VALUE)
tf.config.experimental.enable_op_determinism()
for initializer in initializers_list:
    print(f"Running {initializer}")

    for iteration in range(1):
        # In order to get same results across multiple runs from an initializer,
        # you can specify a seed value.
        result = float(initializer(seed=SEED_VALUE)(shape=(1, 1)))
        print(f"\tIteration --> {iteration} // Result --> {result}")
    print("\n")
# Out:
# Running <class 'keras.src.initializers.random_initializers.RandomNormal'>
# 	Iteration --> 0 // Result --> 0.012323939241468906
#
#
# Running <class 'keras.src.initializers.random_initializers.RandomUniform'>
# 	Iteration --> 0 // Result --> 0.025454167276620865
#
#
# Running <class 'keras.src.initializers.random_initializers.TruncatedNormal'>
# 	Iteration --> 0 // Result --> 0.012323939241468906
#
#
# Running <class 'keras.src.initializers.random_initializers.VarianceScaling'>
# 	Iteration --> 0 // Result --> 0.2802087366580963
#
#
# Running <class 'keras.src.initializers.random_initializers.GlorotNormal'>
# 	Iteration --> 0 // Result --> 0.2802087366580963
#
#
# Running <class 'keras.src.initializers.random_initializers.GlorotUniform'>
# 	Iteration --> 0 // Result --> 0.8817580938339233
#
#
# Running <class 'keras.src.initializers.random_initializers.HeNormal'>
# 	Iteration --> 0 // Result --> 0.39627498388290405
#
#
# ...

# %% [markdown]
# # 1. Carga de los datos

# %%
# !git clone https://github.com/mateofra/AAS.git
# Out:
# Cloning into 'AAS'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 143 (delta 63), reused 114 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 18.93 MiB | 19.15 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# %ls
# Out:
# sample_data/

# %%
# Completa con el código
dt_train = pd.read_csv('fashion-mnist_trainmini.csv')
dt_test = pd.read_csv('fashion-mnist_testmini.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1500450680.py in <cell line: 0>()
#       1 # Completa con el código
# ----> 2 dt_train = pd.read_csv('fashion-mnist_trainmini.csv')
#       3 dt_test = pd.read_csv('fashion-mnist_testmini.csv')
#
# ...

# %%
def get_name_label(label):
    if label == 0:
        return "T-shirt"
    elif label == 1:
        return "Trouser"
    elif label == 2:
        return "Pullover"
    elif label == 3:
        return "Dress"
    elif label == 4:
        return "Coat"
    elif label == 5:
        return "Sandal"
    elif label == 6:
        return "Shirt"
    elif label == 7:
        return "Sneaker"
    elif label == 8:
        return "Bag"
    elif label == 9:
        return "Ankle boot"

# %% [markdown]
# # 3. Entrenamiento de un perceptrón multicapa
